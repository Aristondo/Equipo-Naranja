# %%
import pandas as pd
import numpy as np

# %%
df_2020= pd.read_excel('2020.xlsx')
df_2021= pd.read_excel('2021.xlsx')
df_2022= pd.read_excel('2022.xlsx')

# %%
df_2020.columns
# Out:
# Index(['Nombre', 'Código NIF', 'Localidad', 'Provincia', 'País',
#        'Código primario CNAE 2009', 'Literal código CNAE 2009 primario',
#        'Fecha constitución', 'Importador / Exportador', 'Países importación',
#        'Países exportación', 'Otros activos líquidos\nmil EUR\n2020',
#        'Inmovilizado\nmil EUR\n2020', 'Inmovilizado inmaterial\nmil EUR\n2020',
#        'Inmovilizado material\nmil EUR\n2020',
#        'Otros activos fijos\nmil EUR\n2020',
#        'Activo circulante\nmil EUR\n2020', 'Existencias\nmil EUR\n2020',
#        'Deudores\nmil EUR\n2020', 'Tesorería\nmil EUR\n2020',
#        'Total activo\nmil EUR\n2020', 'Capital suscrito\nmil EUR\n2020',
#        'Otros fondos propios\nmil EUR\n2020', 'Pasivo fijo\nmil EUR\n2020',
#        'Acreedores a L. P.\nmil EUR\n2020',
#        'Otros pasivos fijos\nmil EUR\n2020', 'Pasivo líquido\nmil EUR\n2020',
#        'Deudas financieras\nmil EUR\n2020',
#        'Acreedores comerciales\nmil EUR\n2020',
#        'Otros pasivos líquidos\nmil EUR\n2020',
#        'Total pasivo y capital propio\nmil EUR\n2020',
#        'Número empleados\n2020', 'Ingresos de explotación\nmil EUR\n2020',
#        'Importe neto Cifra de Ventas\nmil EUR\n2020',
#        'Consumo de mercaderías y de materias\nmil EUR\n2020',
#        'Resultado bruto\nmil EUR\n2020',
#        'Otros gastos de explotación\nmil EUR\n2020',
#        'Resultado Explotación\nmil EUR\n2020',
#        'Ingresos financieros\nmil EUR\n2020',
#        'Gastos financieros\nmil EUR\n2020',
#        'Resultado financiero\nmil EUR\n2020',
#        'Result. ordinarios antes Impuestos\nmil EUR\n2020',
#        'Impuestos sobre sociedades\nmil EUR\n2020',
#        'Resultado Actividades Ordinarias\nmil EUR\n2020',
#        'Ingresos extraordinarios\nmil EUR\n2020',
#        'Gastos extraordinarios\nmil EUR\n2020',
#        'Resultados actividades extraordinarias\nmil EUR\n2020',
#        'Resultado del Ejercicio\nmil EUR\n2020', 'Materiales\nmil EUR\n2020',
#        'Gastos de personal\nmil EUR\n2020',
#        'Dotaciones para amortiz. de inmovil.\nmil EUR\n2020',
#        'Otros Conceptos de Explotación\nmil EUR\n2020',
#        'Gastos financieros y gastos asimilados\nmil EUR\n2020'],
#       dtype='object')

# %%
df_2020_ingexp = df_2020[['Código NIF','Ingresos de explotación\nmil EUR\n2020']]
df_2020_ingexp.replace('n.d.',np.nan,inplace=True)
df_2020_ingexp.isna().sum()
# Out:
# /tmp/ipykernel_3881/2950529900.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_ingexp.replace('n.d.',np.nan,inplace=True)
# Código NIF                                   0
# Ingresos de explotación\nmil EUR\n2020    7574
# dtype: int64

# %%
df_2022_col=df_2022[['Nombre', 'Código NIF', 'Localidad',
       'Provincia', 'País', 'Código primario CNAE 2009',
       'Literal código CNAE 2009 primario', 'Fecha constitución',
       'Importador / Exportador', 'Países importación', 'Países exportación','Resultado del Ejercicio\nmil EUR\n2022',
       'Total activo\nmil EUR\n2022', 'Ingresos de explotación\nmil EUR\n2022', 'Activo circulante\nmil EUR\n2022', 
       'Pasivo líquido\nmil EUR\n2022', 'Resultado Explotación\nmil EUR\n2022',  
       'Otros activos líquidos\nmil EUR\n2022','Capital suscrito\nmil EUR\n2022',
       'Otros fondos propios\nmil EUR\n2022',]]
df_2022_col.head()
# Out:
#                                        Nombre Código NIF Localidad Provincia  \
# 0        IBERDROLA CLIENTES SOCIEDAD ANONIMA.  A95758389    BILBAO   Vizcaya
# 1                     PAN AMERICAN ENERGY SL.  B88260203    BILBAO   Vizcaya
# 2  IBERDROLA ENERGIA ESPAÑA SOCIEDAD ANONIMA.  A95758371    BILBAO   Vizcaya
# 3             ALVEAN SUGAR SOCIEDAD LIMITADA.  B95773057    BILBAO   Vizcaya
# 4                 IBERDROLA, SOCIEDAD ANONIMA  A48010615    BILBAO   Vizcaya
#
#      País  Código primario CNAE 2009  \
# 0  ESPANA                       3514
# 1  ESPANA                       6420
# 2  ESPANA                       4611
# 3  ESPANA                       4636
# 4  ESPANA                       6420
#
#                    Literal código CNAE 2009 primario   Fecha constitución  \
# 0                      Comercio de energía eléctrica  2014-03-17 00:00:00
# 1              Actividades de las sociedades holding  1997-09-29 00:00:00
# 2  Intermediarios del comercio de materias primas...  2014-03-17 00:00:00
# 3  Comercio al por mayor de azúcar, chocolate y c...  2014-07-17 00:00:00
# 4              Actividades de las sociedades holding  1901-07-19 00:00:00
#
#    Importador / Exportador Países importación Países exportación  \
# 0               Exportador                NaN                 UE
# 1               Exportador                NaN          ARGENTINA
# 2               Exportador                NaN                 UE
# 3  Importador / Exportador                NaN                NaN
# 4               Exportador                NaN                 UE
#
#    Resultado del Ejercicio\nmil EUR\n2022  Total activo\nmil EUR\n2022  \
# 0                                627609.0                    3252348.0
# 1                                477940.0                   14448655.0
# 2                                923275.0                    7184141.0
# 3                                 67407.0                     835248.0
# 4                               2840000.0                   53343000.0
#
#    Ingresos de explotación\nmil EUR\n2022  Activo circulante\nmil EUR\n2022  \
# 0                              14505887.0                         2768672.0
# 1                               5112628.0                         1700432.0
# 2                               5004915.0                         3882794.0
# 3                               3994744.0                          799119.0
# 4                               3058000.0                         3301000.0
#
#    Pasivo líquido\nmil EUR\n2022  Resultado Explotación\nmil EUR\n2022  \
# 0                      1678552.0                              808712.0
# 1                      1727270.0                              578995.0
# 2                      2219290.0                             1564280.0
# 3                       487710.0                               84885.0
# 4                     10228000.0                             3167000.0
#
#    Otros activos líquidos\nmil EUR\n2022  Capital suscrito\nmil EUR\n2022  \
# 0                               439508.0                         155295.0
# 1                               742038.0                        2093033.0
# 2                              2676848.0                        1985452.0
# 3                               352001.0                          30857.0
# 4                              3003000.0                        4772000.0
#
#    Otros fondos propios\nmil EUR\n2022
# 0                            1344809.0
# 1                            5777889.0
# 2                            -772285.0
# 3                             312183.0
# 4                           26909000.0

# %% [markdown]
# Descartamos el df del 2021 al ver una gran cantidad de duplicados y al tener muchos menos datos no repetidos que el resto de los df.

# %%
nif_comunes =  set(df_2020['Código NIF'])&set(df_2022['Código NIF'])
len(nif_comunes)
# Out:
# 39464

# %%
paises=list(df_2022_col[['Países exportación']].value_counts().index)
paises
# Out:
# [('UE',),
#  ('EUROPA',),
#  ('FRANCIA',),
#  ('PORTUGAL',),
#  ('UE;EEUU',),
#  ('MEXICO',),
#  ('AMERICA;ASIA;EUROPA',),
#  ('CENTRO AMERICA;SUDAMERICA;UE',),
#  ('FRANCIA;PORTUGAL',),
#  ('ITALIA',),
#  ('AMERICA;UE',),
#  ('SUDAMERICA;UE',),
#  ('ALEMANIA;FRANCIA',),
#  ('CHINA',),
#  ('ALEMANIA',),
#  ('CUBA',),
#  ('AFRICA;AMERICA;ASIA;EUROPA;OCEANIA',),
#  ('AFRICA;AMERICA;ASIA;EUROPA',),
#  ('EEUU',),
#  ('BELGICA',),
#  ('AMERICA;EUROPA',),
#  ('AMERICA',),
#  ('EUROPA;CENTRO AMERICA;SUDAMERICA',),
#  ('ALEMANIA;FRANCIA;ITALIA;PORTUGAL',),
#  ('EUROPA;EEUU',),
#  ('SUECIA',),
#  ('ALEMANIA;EEUU;UK',),
#  ('CENTRO AMERICA;SUDAMERICA',),
#  ('EUROPA;SUDAMERICA',),
#  ('UE;AMERICA',),
#  ('FRANCIA;UK;RUMANIA',),
#  ('EUROPA;AUSTRALIA;CANADA;EEUU;JAPON;NUEVA ZELANDA',),
#  ('INDIA',),
#  ('INDIA;FRANCIA;CHINA',),
#  ('EUROPA;ALEMANIA;SUECIA;FRANCIA;UK',),
#  ('INDIA;PORTUGAL',),
#  ('EUROPA;ORIENTE MEDIO;CHINA;EGIPTO',),
#  ('IRLANDA;EEUU;AUSTRALIA;FRANCIA;CANADA',),
#  ('ITALIA;FRANCIA',),
#  ('ITALIA;FRANCIA;JAPON;ALEMANIA;AUSTRIA;EEUU;UK;ARABIA SAUDI',),
#  ('ITALIA;POLONIA;UK;SUDAFRICA',),
#  ('ITALIA;PORTUGAL',),
#  ('KAZAJSTAN',),
#  ('EUROPA;UK',),
#  ('INDIA;SUECIA',),
#  ('FRANCIA;SUDAMERICA',),
#  ('EUROPA;BRASIL;SUDAFRICA',),
#  ('FRANCIA;PORTUGAL;UK;BELGICA;DINAMARCA;ALEMANIA;PAISES BAJOS',),
#  ('FRANCIA;ALEMANIA',),
#  ('FRANCIA;ALEMANIA;SUIZA;AUSTRIA;BELGICA',),
#  ('FRANCIA;PORTUGAL;ITALIA',),
#  ('FRANCIA;BELGICA;PORTUGAL',),
#  ('FRANCIA;EUROPA',),
#  ('FRANCIA;ITALIA',),
#  ('EUROPA;EEUU;MEXICO',),
#  ('EUROPA;NORTE AMERICA;SUDAMERICA;ARGENTINA;COLOMBIA;EEUU;MEXICO',),
#  ('EUROPA;EEUU;RUSIA;TAIWAN',),
#  ('FRANCIA;MARRUECOS;SENEGAL',),
#  ('FRANCIA;ITALIA;PORTUGAL;UK',),
#  ('FRANCIA;ITALIA;PAISES BAJOS;UK;ALEMANIA;POLONIA;COLOMBIA;BRASIL;MEXICO;MALI;SUECIA;COSTA DE MARFIL',),
#  ('FRANCIA;UK',),
#  ('UE;AFRICA',),
#  ('UE;ALEMANIA;AUSTRALIA;EEUU;FRANCIA;INDIA;JAPON',),
#  ('UE;ALEMANIA;BELGICA;FRANCIA',),
#  ('UE;ALEMANIA;EEUU;UK;SUIZA',),
#  ('UE;AMERICA;ARABIA SAUDI',),
#  ('UE;ANDORRA',),
#  ('UE;AUSTRALIA;INDONESIA;MALASIA',),
#  ('AFRICA;AMERICA;ASIA;ORIENTE MEDIO;UE',),
#  ('AFRICA;AMERICA;EUROPA',),
#  ('AFRICA;AMERICA;EUROPA;ALEMANIA;AUSTRALIA;FRANCIA;GROENLANDIA;ITALIA;NUEVA ZELANDA;POLONIA',),
#  ('EUROPA;ALEMANIA;BELGICA;CHINA;JAPON',),
#  ('AFRICA;AMERICA;UE',),
#  ('AFRICA;ASIA;CENTRO AMERICA;SUDAMERICA;UE;EEUU',),
#  ('AFRICA;ASIA;EUROPA',),
#  ('UK;PAISES BAJOS',),
#  ('UE;CANADA;EEUU;UK',),
#  ('UE;CHINA;EEUU',),
#  ('UE;CHINA;HONG KONG',),
#  ('UE;CHINA;MEXICO',),
#  ('UE;IRAN',),
#  ('AFRICA DEL NORTE;ORIENTE MEDIO;SUDAMERICA;UE',),
#  ('AFRICA;AMERICA;EUROPA;OCEANIA',),
#  ('MARRUECOS',),
#  ('MEXICO;ALEMANIA;EEUU;CHINA',),
#  ('MEXICO;CUBA;ITALIA;FRANCIA',),
#  ('MEXICO;ECUADOR;COLOMBIA;POLONIA;ESLOVENIA;LIBIA;INDIA;QATAR;ARABIA SAUDI',),
#  ('MEXICO;POLONIA',),
#  ('MEXICO;PORTUGAL;RUMANIA',),
#  ('NIGERIA;FILIPINAS',),
#  ('ORIENTE MEDIO;UCRANIA;RUSIA',),
#  ('PAISES BAJOS;FRANCIA;ITALIA;UK;ALEMANIA',),
#  ('PAKISTAN',),
#  ('TURQUIA;ESLOVENIA;MEXICO;EEUU;CANADA;INDONESIA;AUSTRALIA;INDIA;COREA DEL SUR;CHINA',),
#  ('PORTUGAL;MARRUECOS;TUNEZ;SUDAFRICA;ANGOLA;MOZAMBIQUE',),
#  ('PORTUGAL;SUDAMERICA',),
#  ('REPUBLICA CHECA;UK;MEXICO',),
#  ('REPUBLICA DOMINICANA',),
#  ('RUMANIA',),
#  ('SERBIA;POLONIA;MEXICO;BRASIL;ALEMANIA;ISRAEL;INDIA;PORTUGAL;RUSIA;SUECIA',),
#  ('SUDAMERICA',),
#  ('SUDAMERICA;EEUU',),
#  ('SUECIA;NORUEGA;ALEMANIA;EEUU;FRANCIA;UK;PAISES BAJOS',),
#  ('SUIZA;FRANCIA;ALEMANIA',),
#  ('TUNEZ;PORTUGAL;SUECIA;ALEMANIA;IRLANDA;BELGICA;FRANCIA;PAISES BAJOS;UK',),
#  ('PORTUGAL;CHILE',),
#  ('ALEMANIA;CANADA;EEUU;FRANCIA;PORTUGAL;UK',),
#  ('ALEMANIA;CHINA;COREA DEL SUR;ESLOVAQUIA;EEUU;FRANCIA;HUNGRIA;INDIA;ITALIA;JAPON;MEXICO;POLONIA;PORTUGAL;RUSIA',),
#  ('ALEMANIA;DINAMARCA;FRANCIA;PAISES BAJOS;UK;SUIZA',),
#  ('ALEMANIA;EEUU;FRANCIA',),
#  ('ALEMANIA;ESLOVAQUIA;FRANCIA;REPUBLICA CHECA',),
#  ('ALEMANIA;FRANCIA;ARGENTINA;PAISES BAJOS;MEXICO;BELGICA',),
#  ('ALEMANIA;FRANCIA;ISRAEL;ITALIA;POLONIA',),
#  ('ALEMANIA;FRANCIA;UK;PAISES BAJOS;PORTUGAL;SUIZA',),
#  ('ALEMANIA;INDONESIA',),
#  ('ALEMANIA;PAISES BAJOS',),
#  ('UE;JAPON',),
#  ('AMERICA;ASIA;EUROPA;ARABIA SAUDI;CHILE;COLOMBIA;COSTA RICA;EMIRATOS ARABES UNIDOS;PANAMA;PERU;TURQUIA',),
#  ('AMERICA;ASIA;UE',),
#  ('AMERICA;EUROPA;UE',),
#  ('ANDORRA;CHINA;ECUADOR;EEUU;GHANA;GIBRALTAR;HONG KONG',),
#  ('ARABIA SAUDI;BRASIL;FRANCIA;INDIA;ITALIA;PAISES BAJOS;PORTUGAL',),
#  ('ARABIA SAUDI;COLOMBIA;MEXICO',),
#  ('ARABIA SAUDI;COREA DEL SUR;EEUU;HONG KONG;LITUANIA;PERU;PORTUGAL;RUMANIA;SINGAPUR;VIETNAM',),
#  ('ARGELIA;CANADA;MEXICO;MONTENEGRO',),
#  ('ARGENTINA',),
#  ('ARGENTINA;BULGARIA;ECUADOR',),
#  ('AMERICA;ASIA',),
#  ('AFRICA;AMERICA;ASIA;EUROPA;UE;EEUU',),
#  ('UE;MARRUECOS',),
#  ('AFRICA;ASIA;EUROPA;CENTRO AMERICA;SUDAMERICA',),
#  ('UE;PORTUGAL',),
#  ('UE;SUECIA',),
#  ('UE;UK',),
#  ('UE;UK;TURQUIA',),
#  ('UK',),
#  ('UK;ALEMANIA;BELGICA;EEUU;IRLANDA;FRANCIA;ITALIA;EUROPA;JAPON',),
#  ('UK;FRANCIA;ALEMANIA;EEUU;RUSIA;POLONIA',),
#  ('ALEMANIA;CANADA;CHINA;FRANCIA;GRECIA;ITALIA;PORTUGAL;RUSIA',),
#  ('AFRICA;ASIA;EUROPA;CENTRO AMERICA;SUDAMERICA;UE;AUSTRALIA;EEUU',),
#  ('AFRICA;ASIA;EUROPA;NORTE AMERICA;CENTRO AMERICA;SUDAMERICA;ORIENTE MEDIO;AUSTRALIA;NUEVA ZELANDA',),
#  ('AFRICA;CENTRO AMERICA;SUDAMERICA',),
#  ('AFRICA;UE',),
#  ('ALEMANIA;ANDORRA;ARABIA SAUDI;ARGENTINA;AUSTRALIA;AUSTRIA;BAHREIN;BELGICA;BRASIL;BULGARIA;CANADA;CHILE;COLOMBIA;COREA DEL SUR;COSTA RICA;DINAMARCA;ECUADOR;EGIPTO;EMIRATOS ARABES UNIDOS;ESLOVENIA;EEUU',),
#  ('ALEMANIA;ARGENTINA;AUSTRIA;BELGICA;BRASIL;CANADA;CHINA;COREA DEL SUR;ECUADOR;EGIPTO;EEUU;FRANCIA;GRECIA;HONG KONG;ISRAEL;ITALIA;MARRUECOS;PAKISTAN;POLONIA;PORTUGAL;UK;REPUBLICA CHECA;RUMANIA;RUSIA;SUI',),
#  ('ALEMANIA;ARGENTINA;AUSTRIA;BELGICA;CHINA;EMIRATOS ARABES UNIDOS;EEUU;FINLANDIA;FRANCIA;INDIA;ITALIA;JAPON;MALASIA;MEXICO;UK;SUECIA;SUIZA',),
#  ('ALEMANIA;BELGICA;CANADA;COLOMBIA;EEUU;FINLANDIA;HUNGRIA;IRLANDA;ITALIA;JAPON;MEXICO;PAISES BAJOS;POLONIA;UK;SUECIA',),
#  ('ALEMANIA;BELGICA;EEUU;IRLANDA;UK;SUIZA',),
#  ('ALEMANIA;BELGICA;FRANCIA;ITALIA;REPUBLICA CHECA;SUECIA;SUIZA',),
#  ('ALEMANIA;BELGICA;PAISES BAJOS',),
#  ('AFRICA',),
#  ('CHILE;COLOMBIA;COREA DEL SUR;EEUU',),
#  ('CHILE;COLOMBIA;PERU',),
#  ('CHILE;JAPON;REPUBLICA DOMINICANA;SUIZA',),
#  ('CHINA;EEUU;SUIZA',),
#  ('CHINA;FRANCIA;RUMANIA;RUSIA',),
#  ('CHINA;UE',),
#  ('CHINA;UK;EEUU',),
#  ('COLOMBIA;EEUU;FRANCIA;POLONIA;PORTUGAL;RUSIA;SUDAFRICA',),
#  ('COLOMBIA;MALASIA',),
#  ('CUBA;MARRUECOS',),
#  ('ARGENTINA;URUGUAY',),
#  ('CUBA;VENEZUELA',),
#  ('DINAMARCA',),
#  ('DINAMARCA;FINLANDIA;POLONIA;MEXICO;PANAMA;EEUU;JAPON;CANADA;ALEMANIA;UK',),
#  ('EEUU;ASIA;EUROPA;CENTRO AMERICA',),
#  ('EEUU;BRASIL;MEXICO',),
#  ('EEUU;MEXICO',),
#  ('EEUU;RUSIA',),
#  ('EEUU;UE',),
#  ('EGIPTO;AMERICA;EUROPA',),
#  ('EMIRATOS ARABES UNIDOS',),
#  ('ESLOVAQUIA;MEXICO',),
#  ('CUBA;MEXICO',),
#  ('ASIA;EUROPA',),
#  ('ASIA;EUROPA;AFRICA DEL NORTE;CENTRO AMERICA;SUDAMERICA;BRASIL;UK',),
#  ('ASIA;EUROPA;BRASIL;EEUU',),
#  ('ASIA;EUROPA;PAISES ARABES',),
#  ('ASIA;FINLANDIA',),
#  ('AUSTRALIA;EMIRATOS ARABES UNIDOS;MEXICO',),
#  ('BELGICA;BRASIL;EEUU;JAPON;PAISES BAJOS;SUIZA',),
#  ('BELGICA;EEUU;LUXEMBURGO;PAISES BAJOS;UK',),
#  ('BELGICA;FRANCIA;ITALIA;UK',),
#  ('BELGICA;FRANCIA;PORTUGAL',),
#  ('CENTRO AMERICA;SUDAMERICA;UE;MEXICO',),
#  ('BELGICA;HUNGRIA;REPUBLICA CHECA;SUIZA',),
#  ('BELGICA;MEXICO;PANAMA',),
#  ('BELGICA;PORTUGAL;RUMANIA;SUECIA',),
#  ('BELGICA;VENEZUELA;UK',),
#  ('BRASIL',),
#  ('BRASIL;CAMERUN;COSTA DE MARFIL;JAMAICA;MEXICO',),
#  ('BRASIL;CHILE;COLOMBIA;COSTA DE MARFIL;CUBA;ECUADOR;MEXICO;PERU;SEYCHELLES',),
#  ('BRASIL;PERU;REPUBLICA CHECA;SUIZA;URUGUAY',),
#  ('CANADA;COREA DEL SUR;FRANCIA;ITALIA',),
#  ('CENTRO AMERICA;ARGENTINA;CHILE;COLOMBIA;ECUADOR;MEXICO;PERU',),
#  ('CENTRO AMERICA;SUDAMERICA;ESCANDINAVIA;UE;MEXICO',),
#  ('BELGICA;FRANCIA;SUIZA',)]

# %%
df_2022_col_comunes =  df_2022_col[df_2022_col['Código NIF'].isin(nif_comunes)]
df_2022_col_comunes.drop_duplicates(inplace=True)
df_2022_col_comunes.reset_index(inplace=True, drop=True)
df_2022_col_comunes.head()
# Out:
# /tmp/ipykernel_3881/981536150.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_col_comunes.drop_duplicates(inplace=True)
#                                        Nombre Código NIF Localidad Provincia  \
# 0        IBERDROLA CLIENTES SOCIEDAD ANONIMA.  A95758389    BILBAO   Vizcaya
# 1                     PAN AMERICAN ENERGY SL.  B88260203    BILBAO   Vizcaya
# 2  IBERDROLA ENERGIA ESPAÑA SOCIEDAD ANONIMA.  A95758371    BILBAO   Vizcaya
# 3             ALVEAN SUGAR SOCIEDAD LIMITADA.  B95773057    BILBAO   Vizcaya
# 4                 IBERDROLA, SOCIEDAD ANONIMA  A48010615    BILBAO   Vizcaya
#
#      País  Código primario CNAE 2009  \
# 0  ESPANA                       3514
# 1  ESPANA                       6420
# 2  ESPANA                       4611
# 3  ESPANA                       4636
# 4  ESPANA                       6420
#
#                    Literal código CNAE 2009 primario   Fecha constitución  \
# 0                      Comercio de energía eléctrica  2014-03-17 00:00:00
# 1              Actividades de las sociedades holding  1997-09-29 00:00:00
# 2  Intermediarios del comercio de materias primas...  2014-03-17 00:00:00
# 3  Comercio al por mayor de azúcar, chocolate y c...  2014-07-17 00:00:00
# 4              Actividades de las sociedades holding  1901-07-19 00:00:00
#
#    Importador / Exportador Países importación Países exportación  \
# 0               Exportador                NaN                 UE
# 1               Exportador                NaN          ARGENTINA
# 2               Exportador                NaN                 UE
# 3  Importador / Exportador                NaN                NaN
# 4               Exportador                NaN                 UE
#
#    Resultado del Ejercicio\nmil EUR\n2022  Total activo\nmil EUR\n2022  \
# 0                                627609.0                    3252348.0
# 1                                477940.0                   14448655.0
# 2                                923275.0                    7184141.0
# 3                                 67407.0                     835248.0
# 4                               2840000.0                   53343000.0
#
#    Ingresos de explotación\nmil EUR\n2022  Activo circulante\nmil EUR\n2022  \
# 0                              14505887.0                         2768672.0
# 1                               5112628.0                         1700432.0
# 2                               5004915.0                         3882794.0
# 3                               3994744.0                          799119.0
# 4                               3058000.0                         3301000.0
#
#    Pasivo líquido\nmil EUR\n2022  Resultado Explotación\nmil EUR\n2022  \
# 0                      1678552.0                              808712.0
# 1                      1727270.0                              578995.0
# 2                      2219290.0                             1564280.0
# 3                       487710.0                               84885.0
# 4                     10228000.0                             3167000.0
#
#    Otros activos líquidos\nmil EUR\n2022  Capital suscrito\nmil EUR\n2022  \
# 0                               439508.0                         155295.0
# 1                               742038.0                        2093033.0
# 2                              2676848.0                        1985452.0
# 3                               352001.0                          30857.0
# 4                              3003000.0                        4772000.0
#
#    Otros fondos propios\nmil EUR\n2022
# 0                            1344809.0
# 1                            5777889.0
# 2                            -772285.0
# 3                             312183.0
# 4                           26909000.0

# %%
df_2020_comunes =  df_2020[df_2020['Código NIF'].isin(nif_comunes)]
df_2020_comunes.drop_duplicates(inplace=True)
df_2020_comunes.reset_index(inplace=True, drop=True)
df_2020_comunes.head()
# Out:
# /tmp/ipykernel_3881/3413841440.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_comunes.drop_duplicates(inplace=True)
#                                               Nombre Código NIF Localidad  \
# 0               PETROLEOS DEL NORTE SOCIEDAD ANONIMA  A48053243    MUSKIZ
# 1                      SIDENOR ACEROS ESPECIALES SLU  B01292903   BASAURI
# 2  BRIDGESTONE HISPANIA MANUFACTURING SOCIEDAD LI...  B95922688   BASAURI
# 3  COMPAÑIA NORTEÑA DE BEBIDAS GASEOSAS NORBEGA S...  B48023030  GALDAKAO
# 4    BAHIA DE BIZKAIA ELECTRICIDAD SOCIEDAD LIMITADA  B48969877  ZIERBENA
#
#   Provincia    País  Código primario CNAE 2009  \
# 0   Vizcaya  ESPANA                       1920
# 1   Vizcaya  ESPANA                       2410
# 2   Vizcaya  ESPANA                       2211
# 3   Vizcaya  ESPANA                       1107
# 4   Vizcaya  ESPANA                       3519
#
#                    Literal código CNAE 2009 primario   Fecha constitución  \
# 0                                 Refino de petróleo  1968-01-01 00:00:00
# 1  Fabricación de productos básicos de hierro, ac...  1999-11-18 00:00:00
# 2  Fabricación de neumáticos y cámaras de caucho;...  2018-05-31 00:00:00
# 3  Fabricación de bebidas no alcohólicas; producc...  1955-07-06 00:00:00
# 4     Producción de energía eléctrica de otros tipos  1998-04-30 00:00:00
#
#    Importador / Exportador Países importación  ...  \
# 0  Importador / Exportador                 UE  ...
# 1  Importador / Exportador                 UE  ...
# 2               Exportador                NaN  ...
# 3               Importador                 UE  ...
# 4               Importador                NaN  ...
#
#   Resultado Actividades Ordinarias\nmil EUR\n2020  \
# 0                                         -140086
# 1                                          -39853
# 2                                            1792
# 3                                       18209.709
# 4                                        1146.572
#
#   Ingresos extraordinarios\nmil EUR\n2020  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Gastos extraordinarios\nmil EUR\n2020  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Resultados actividades extraordinarias\nmil EUR\n2020  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Resultado del Ejercicio\nmil EUR\n2020 Materiales\nmil EUR\n2020  \
# 0                                -140086                   3362167
# 1                                 -39853                    244284
# 2                                   1792                    282346
# 3                              18209.709                608261.681
# 4                               1146.572                132891.325
#
#   Gastos de personal\nmil EUR\n2020  \
# 0                             93672
# 1                             90310
# 2                            153205
# 3                         19561.039
# 4                          3818.954
#
#   Dotaciones para amortiz. de inmovil.\nmil EUR\n2020  \
# 0                                              97175
# 1                                              22212
# 2                                              43388
# 3                                          14293.748
# 4                                          23742.362
#
#   Otros Conceptos de Explotación\nmil EUR\n2020  \
# 0                                       -225893
# 1                                       -136437
# 2                                        -76136
# 3                                    -61482.757
# 4                                    -15559.192
#
#   Gastos financieros y gastos asimilados\nmil EUR\n2020
# 0                                               2613
# 1                                               3684
# 2                                                548
# 3                                                NaN
# 4                                             64.766
#
# [5 rows x 53 columns]

# %%
df_2022_comunes =  df_2022[df_2022['Código NIF'].isin(nif_comunes)]
df_2022_comunes.reset_index(inplace=True, drop=True)
df_2022_comunes.drop_duplicates(inplace=True)
df_2022_comunes.reset_index(inplace=True, drop=True)
df_2022_comunes.head()
# Out:
# /tmp/ipykernel_3881/491666476.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_comunes.drop_duplicates(inplace=True)
#                                        Nombre Código NIF Localidad Provincia  \
# 0        IBERDROLA CLIENTES SOCIEDAD ANONIMA.  A95758389    BILBAO   Vizcaya
# 1                     PAN AMERICAN ENERGY SL.  B88260203    BILBAO   Vizcaya
# 2  IBERDROLA ENERGIA ESPAÑA SOCIEDAD ANONIMA.  A95758371    BILBAO   Vizcaya
# 3             ALVEAN SUGAR SOCIEDAD LIMITADA.  B95773057    BILBAO   Vizcaya
# 4                 IBERDROLA, SOCIEDAD ANONIMA  A48010615    BILBAO   Vizcaya
#
#      País  Código primario CNAE 2009  \
# 0  ESPANA                       3514
# 1  ESPANA                       6420
# 2  ESPANA                       4611
# 3  ESPANA                       4636
# 4  ESPANA                       6420
#
#                    Literal código CNAE 2009 primario   Fecha constitución  \
# 0                      Comercio de energía eléctrica  2014-03-17 00:00:00
# 1              Actividades de las sociedades holding  1997-09-29 00:00:00
# 2  Intermediarios del comercio de materias primas...  2014-03-17 00:00:00
# 3  Comercio al por mayor de azúcar, chocolate y c...  2014-07-17 00:00:00
# 4              Actividades de las sociedades holding  1901-07-19 00:00:00
#
#    Importador / Exportador Países importación  ...  \
# 0               Exportador                NaN  ...
# 1               Exportador                NaN  ...
# 2               Exportador                NaN  ...
# 3  Importador / Exportador                NaN  ...
# 4               Exportador                NaN  ...
#
#   Resultado Actividades Ordinarias\nmil EUR\n2022  \
# 0                                        627609.0
# 1                                        477940.0
# 2                                        923275.0
# 3                                         67407.0
# 4                                       2840000.0
#
#    Ingresos extraordinarios\nmil EUR\n2022  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Gastos extraordinarios\nmil EUR\n2022  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Resultados actividades extraordinarias\nmil EUR\n2022  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Resultado del Ejercicio\nmil EUR\n2022  Materiales\nmil EUR\n2022  \
# 0                                627609.0                 12868251.0
# 1                                477940.0                  1134150.0
# 2                                923275.0                  4046923.0
# 3                                 67407.0                  3874052.0
# 4                               2840000.0                        NaN
#
#    Gastos de personal\nmil EUR\n2022  \
# 0                            77500.0
# 1                           489580.0
# 2                            26987.0
# 3                            20475.0
# 4                           166000.0
#
#    Dotaciones para amortiz. de inmovil.\nmil EUR\n2022  \
# 0                                             9612.0
# 1                                           805893.0
# 2                                             2654.0
# 3                                             1945.0
# 4                                            72000.0
#
#    Otros Conceptos de Explotación\nmil EUR\n2022  \
# 0                                      -741812.0
# 1                                     -2104010.0
# 2                                       635929.0
# 3                                       -13387.0
# 4                                       347000.0
#
#    Gastos financieros y gastos asimilados\nmil EUR\n2022
# 0                                             1502.0
# 1                                           488731.0
# 2                                             9620.0
# 3                                            12819.0
# 4                                           322000.0
#
# [5 rows x 54 columns]

# %%
df_2022_col_comunes.columns
# Out:
# Index(['Nombre', 'Código NIF', 'Localidad', 'Provincia', 'País',
#        'Código primario CNAE 2009', 'Literal código CNAE 2009 primario',
#        'Fecha constitución', 'Importador / Exportador', 'Países importación',
#        'Países exportación', 'Resultado del Ejercicio\nmil EUR\n2022',
#        'Total activo\nmil EUR\n2022', 'Ingresos de explotación\nmil EUR\n2022',
#        'Activo circulante\nmil EUR\n2022', 'Pasivo líquido\nmil EUR\n2022',
#        'Resultado Explotación\nmil EUR\n2022',
#        'Otros activos líquidos\nmil EUR\n2022',
#        'Capital suscrito\nmil EUR\n2022',
#        'Otros fondos propios\nmil EUR\n2022'],
#       dtype='object')

# %%
df_2020_comunes.replace('n.d.',np.nan,inplace=True)
df_2022_comunes.replace('n.d.',np.nan,inplace=True)
df_2022_col_comunes.replace('n.d.',np.nan,inplace=True)
# Out:
# /tmp/ipykernel_3881/3976597485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_comunes.replace('n.d.',np.nan,inplace=True)
# /tmp/ipykernel_3881/3976597485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_comunes.replace('n.d.',np.nan,inplace=True)
# /tmp/ipykernel_3881/3976597485.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_col_comunes.replace('n.d.',np.nan,inplace=True)

# %%
print(df_2022_col_comunes.isna().sum())
# Out:
# Nombre                                        0
# Código NIF                                    0
# Localidad                                     1
# Provincia                                     0
# País                                          0
# Código primario CNAE 2009                     0
# Literal código CNAE 2009 primario             0
# Fecha constitución                           14
# Importador / Exportador                       0
# Países importación                        37019
# Países exportación                        38496
# Resultado del Ejercicio\nmil EUR\n2022    10253
# Total activo\nmil EUR\n2022               10106
# Ingresos de explotación\nmil EUR\n2022    11011
# Activo circulante\nmil EUR\n2022          10121
# Pasivo líquido\nmil EUR\n2022             10341
# Resultado Explotación\nmil EUR\n2022      10217
# Otros activos líquidos\nmil EUR\n2022     10509
# Capital suscrito\nmil EUR\n2022           10107
# Otros fondos propios\nmil EUR\n2022       10134
# dtype: int64

# %%
df_2022_col_comunes=df_2022_col_comunes[df_2022_col_comunes['Total activo\nmil EUR\n2022'].notna()]
df_2022_col_comunes.isna().sum()
# Out:
# Nombre                                        0
# Código NIF                                    0
# Localidad                                     0
# Provincia                                     0
# País                                          0
# Código primario CNAE 2009                     0
# Literal código CNAE 2009 primario             0
# Fecha constitución                            5
# Importador / Exportador                       0
# Países importación                        27301
# Países exportación                        28557
# Resultado del Ejercicio\nmil EUR\n2022      147
# Total activo\nmil EUR\n2022                   0
# Ingresos de explotación\nmil EUR\n2022      905
# Activo circulante\nmil EUR\n2022             15
# Pasivo líquido\nmil EUR\n2022               235
# Resultado Explotación\nmil EUR\n2022        111
# Otros activos líquidos\nmil EUR\n2022       403
# Capital suscrito\nmil EUR\n2022               1
# Otros fondos propios\nmil EUR\n2022          28
# dtype: int64

# %%
df_2020_2022=df_2022_col_comunes.merge(df_2020_ingexp, on='Código NIF', how='left')

# %%
# ETXEKOLANA
df_2020_2022['Ingresos de explotación\nmil EUR\n2020'].apply(lambda x: df_2020_2022['Ingresos de explotación\nmil EUR\n2022'] if x == np.nan else x )
# Out:
# 0          7385719
# 1          2591452
# 2          5720173
# 3          3199090
# 4          2880000
#            ...
# 29353           70
# 29354          NaN
# 29355          NaN
# 29356    443.47968
# 29357    296.04221
# Name: Ingresos de explotación\nmil EUR\n2020, Length: 29358, dtype: object

# %%
print(len(df_2022))
print(len(df_2020_2022))
df_2020_2022.isna().sum()
# Out:
# 39479
# 29358
# Nombre                                        0
# Código NIF                                    0
# Localidad                                     0
# Provincia                                     0
# País                                          0
# Código primario CNAE 2009                     0
# Literal código CNAE 2009 primario             0
# Fecha constitución                            5
# Importador / Exportador                       0
# Países importación                        27301
# Países exportación                        28557
# Resultado del Ejercicio\nmil EUR\n2022      147
# Total activo\nmil EUR\n2022                   0
# Ingresos de explotación\nmil EUR\n2022      905
# Activo circulante\nmil EUR\n2022             15
# Pasivo líquido\nmil EUR\n2022               235
# Resultado Explotación\nmil EUR\n2022        111
# Otros activos líquidos\nmil EUR\n2022       403
# Capital suscrito\nmil EUR\n2022               1
# Otros fondos propios\nmil EUR\n2022          28
# Ingresos de explotación\nmil EUR\n2020     3378
# dtype: int64

# %%
print(df_2022_comunes.isna().sum())
# Out:
# Nombre                                                       0
# Código NIF                                                   0
# Localidad                                                    1
# Provincia                                                    0
# País                                                         0
# Código primario CNAE 2009                                    0
# Literal código CNAE 2009 primario                            0
# Fecha constitución                                          14
# Importador / Exportador                                      0
# Países importación                                       37019
# Países exportación                                       38496
# Otros activos líquidos\nmil EUR\n2022                    10509
# Inmovilizado\nmil EUR\n2022                              11886
# Inmovilizado inmaterial\nmil EUR\n2022                   31019
# Inmovilizado material\nmil EUR\n2022                     15112
# Otros activos fijos\nmil EUR\n2022                       18680
# Activo circulante\nmil EUR\n2022                         10121
# Existencias\nmil EUR\n2022                               23953
# Deudores\nmil EUR\n2022                                  12431
# Tesorería\nmil EUR\n2022                                 11037
# Total activo\nmil EUR\n2022                              10106
# Capital suscrito\nmil EUR\n2022                          10107
# Otros fondos propios\nmil EUR\n2022                      10134
# Pasivo fijo\nmil EUR\n2022                               20951
# Acreedores a L. P.\nmil EUR\n2022                        22311
# Otros pasivos fijos\nmil EUR\n2022                       10106
# Pasivo líquido\nmil EUR\n2022                            10341
# Deudas financieras\nmil EUR\n2022                        29308
# Acreedores comerciales\nmil EUR\n2022                    18657
# Otros pasivos líquidos\nmil EUR\n2022                    10573
# Total pasivo y capital propio\nmil EUR\n2022             10106
# Número empleados\nÚlt. año disp.                          9737
# Número empleados\n2022                                   16283
# Ingresos de explotación\nmil EUR\n2022                   11011
# Importe neto Cifra de Ventas\nmil EUR\n2022              12703
# Consumo de mercaderías y de materias\nmil EUR\n2022      17165
# Resultado bruto\nmil EUR\n2022                           10828
# Otros gastos de explotación\nmil EUR\n2022               10202
# Resultado Explotación\nmil EUR\n2022                     10217
# Ingresos financieros\nmil EUR\n2022                      10106
# Gastos financieros\nmil EUR\n2022                        10106
# Resultado financiero\nmil EUR\n2022                      10106
# Result. ordinarios antes Impuestos\nmil EUR\n2022        10261
# Impuestos sobre sociedades\nmil EUR\n2022                16109
# Resultado Actividades Ordinarias\nmil EUR\n2022          10253
# Ingresos extraordinarios\nmil EUR\n2022                  39464
# Gastos extraordinarios\nmil EUR\n2022                    39464
# Resultados actividades extraordinarias\nmil EUR\n2022    39448
# Resultado del Ejercicio\nmil EUR\n2022                   10253
# Materiales\nmil EUR\n2022                                17323
# Gastos de personal\nmil EUR\n2022                        14554
# Dotaciones para amortiz. de inmovil.\nmil EUR\n2022      15840
# Otros Conceptos de Explotación\nmil EUR\n2022            10229
# Gastos financieros y gastos asimilados\nmil EUR\n2022    17904
# dtype: int64

# %%
df_2020_comunes[df_2020_comunes['Total activo\nmil EUR\n2020'].notna()].isna().sum()
# Out:
# Nombre                                                       0
# Código NIF                                                   0
# Localidad                                                    1
# Provincia                                                    0
# País                                                         0
# Código primario CNAE 2009                                    0
# Literal código CNAE 2009 primario                            0
# Fecha constitución                                           8
# Importador / Exportador                                      0
# Países importación                                       30705
# Países exportación                                       32124
# Otros activos líquidos\nmil EUR\n2020                      477
# Inmovilizado\nmil EUR\n2020                               2243
# Inmovilizado inmaterial\nmil EUR\n2020                   24255
# Inmovilizado material\nmil EUR\n2020                      5771
# Otros activos fijos\nmil EUR\n2020                       10360
# Activo circulante\nmil EUR\n2020                            34
# Existencias\nmil EUR\n2020                               15445
# Deudores\nmil EUR\n2020                                   2404
# Tesorería\nmil EUR\n2020                                  1070
# Total activo\nmil EUR\n2020                                  0
# Capital suscrito\nmil EUR\n2020                              1
# Otros fondos propios\nmil EUR\n2020                         98
# Pasivo fijo\nmil EUR\n2020                               11707
# Acreedores a L. P.\nmil EUR\n2020                        13143
# Otros pasivos fijos\nmil EUR\n2020                           0
# Pasivo líquido\nmil EUR\n2020                              319
# Deudas financieras\nmil EUR\n2020                        22140
# Acreedores comerciales\nmil EUR\n2020                     9677
# Otros pasivos líquidos\nmil EUR\n2020                      580
# Total pasivo y capital propio\nmil EUR\n2020                 0
# Número empleados\n2020                                    7138
# Ingresos de explotación\nmil EUR\n2020                    1167
# Importe neto Cifra de Ventas\nmil EUR\n2020               2986
# Consumo de mercaderías y de materias\nmil EUR\n2020       7895
# Resultado bruto\nmil EUR\n2020                             902
# Otros gastos de explotación\nmil EUR\n2020                 174
# Resultado Explotación\nmil EUR\n2020                       213
# Ingresos financieros\nmil EUR\n2020                          0
# Gastos financieros\nmil EUR\n2020                            0
# Resultado financiero\nmil EUR\n2020                          0
# Result. ordinarios antes Impuestos\nmil EUR\n2020          286
# Impuestos sobre sociedades\nmil EUR\n2020                 8198
# Resultado Actividades Ordinarias\nmil EUR\n2020            279
# Ingresos extraordinarios\nmil EUR\n2020                  33061
# Gastos extraordinarios\nmil EUR\n2020                    33061
# Resultados actividades extraordinarias\nmil EUR\n2020    33043
# Resultado del Ejercicio\nmil EUR\n2020                     279
# Materiales\nmil EUR\n2020                                 8113
# Gastos de personal\nmil EUR\n2020                         5144
# Dotaciones para amortiz. de inmovil.\nmil EUR\n2020       6790
# Otros Conceptos de Explotación\nmil EUR\n2020              216
# Gastos financieros y gastos asimilados\nmil EUR\n2020     8306
# dtype: int64

# %% [markdown]
# - ver cuales son las variables que nos interesan y cuales no para eliminarlas, correlacion haciendo dropna?
# - ver las filas que tienen casi todo na por si eliminamos las filas y nos quedamos con las variables
# - interpolacion en alguna de las columnas?
# - pensar que nuevas varibales nos pueden valer.
# -pensar los modelos que vamos a utilizar para el clustering, k-means, clustering jerarquico...
# - organizar los 4 puntos del trabajo(4 archivos diferentes para cada paso):
# 1. Iniciar el proyecto requiere primero comprender el significado de las
# variables presentes en las bases de datos y realizar una depuración de
# estos datos para que sean aptos para trabajar con ellos.
#
# 2. Seguidamente, se procederá al cálculo de los ratios financieros.
#
# 3. Luego, basándose en los cálculos anteriores, se segmentarán las
# empresas mediante el uso de algoritmos de clustering.
#
# 4. Tras segmentar las empresas en diferentes grupos, estos se deberán
# analizar individualmente para poder seleccionar los productos financieros
# que mejor se adecuan a cada tipo de empresa. Se realizará una
# investigación y análisis detallado de una amplia gama de productos
# financieros disponibles en el mercado. Esto incluirá, pero no se limitará a,
# préstamos, líneas de crédito, opciones de inversión, y seguros
# empresariales. Esta investigación deberá utilizar como punto de partida al
# cliente principal, Inetum, y valorar sus posibilidades a la hora de elegir los
# productos financieros.
#
#
# ESTA ES LA DISTRIBUCIÓN QUE SE PROPONE:
# 1. Procesamiento
# 2. Análisis exploratorio
# 3. Selección del modelo
# 4. Optimización del modelo
# 5. Resultados (visualización)
#
# - Cada cosa en un cuaderno diferente
# - De cada cuaderno sale un nuevo fichero de datos
# - El nuevo fichero de datos se utilizará en el siguiente cuaderno
# - Es un proceso secuencial

# %%
df_2020_2022.columns
# Out:
# Index(['Nombre', 'Código NIF', 'Localidad', 'Provincia', 'País',
#        'Código primario CNAE 2009', 'Literal código CNAE 2009 primario',
#        'Fecha constitución', 'Importador / Exportador', 'Países importación',
#        'Países exportación', 'Resultado del Ejercicio\nmil EUR\n2022',
#        'Total activo\nmil EUR\n2022', 'Ingresos de explotación\nmil EUR\n2022',
#        'Activo circulante\nmil EUR\n2022', 'Pasivo líquido\nmil EUR\n2022',
#        'Resultado Explotación\nmil EUR\n2022',
#        'Otros activos líquidos\nmil EUR\n2022',
#        'Capital suscrito\nmil EUR\n2022',
#        'Otros fondos propios\nmil EUR\n2022',
#        'Ingresos de explotación\nmil EUR\n2020'],
#       dtype='object')

# %%
df_2020_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29358 entries, 0 to 29357
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Nombre                                29358 non-null  object
#  1   Código NIF                            29358 non-null  object
#  2   Localidad                             29358 non-null  object
#  3   Provincia                             29358 non-null  object
#  4   País                                  29358 non-null  object
#  5   Código primario CNAE 2009             29358 non-null  int64
#  6   Literal código CNAE 2009 primario     29358 non-null  object
#  7   Fecha constitución                    29353 non-null  object
#  8   Importador / Exportador               29358 non-null  object
#  9   Países importación                    2057 non-null   object
#  10  Países exportación                    801 non-null    object
#  11  Resultado del Ejercicio
# mil EUR
# 2022  29211 non-null  float64
#  12  Total activo
# mil EUR
# 2022             29358 non-null  float64
#  13  Ingresos de explotación
# mil EUR
# 2022  28453 non-null  float64
#  14  Activo circulante
# mil EUR
# 2022        29343 non-null  float64
#  15  Pasivo líquido
# mil EUR
# 2022           29123 non-null  float64
#  16  Resultado Explotación
# mil EUR
# 2022    29247 non-null  float64
#  17  Otros activos líquidos
# mil EUR
# 2022   28955 non-null  float64
#  18  Capital suscrito
# mil EUR
# 2022         29357 non-null  float64
#  19  Otros fondos propios
# mil EUR
# 2022     29330 non-null  float64
#  20  Ingresos de explotación
# mil EUR
# 2020  25980 non-null  object
#  21  Pasivo Total                          29329 non-null  float64
#  22  Endeudamiento                         29329 non-null  float64
#  23  Solvencia                             29109 non-null  float64
#  24  Evolucion_ventas_total                28453 non-null  float64
# dtypes: float64(13), int64(1), object(11)
# memory usage: 5.6+ MB

# %%
df_2020_2022['Pasivo Total']=df_2020_2022['Total activo\nmil EUR\n2022']-df_2020_2022['Capital suscrito\nmil EUR\n2022']-df_2020_2022['Otros fondos propios\nmil EUR\n2022']
df_2020_2022['Endeudamiento']=df_2020_2022['Pasivo Total']/df_2020_2022['Total activo\nmil EUR\n2022']

# %%
df_2020_2022['Solvencia']=df_2020_2022['Activo circulante\nmil EUR\n2022']/df_2020_2022['Pasivo líquido\nmil EUR\n2022']

# %%
df_2020_2022['Ingresos de explotación\nmil EUR\n2022'].value_counts()
# Out:
# Ingresos de explotación\nmil EUR\n2022
# 24.00000     23
# 12.00000     21
# 36.00000     20
# 30.00000     19
# 18.00000     17
#              ..
# 505.42079     1
# 505.53041     1
# 505.54915     1
# 505.67084     1
# 502.35565     1
# Name: count, Length: 27928, dtype: int64

# %%
df_2020_2022['Evolucion_ventas_total']=df_2020_2022['Ingresos de explotación\nmil EUR\n2022']-df_2020_2022['Ingresos de explotación\nmil EUR\n2020'].astype(float)
df_2020_2022['Evolucion_ventas']=df_2020_2022['Evolucion_ventas_total']/df_2020_2022['Ingresos de explotación\nmil EUR\n2020']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df_2020_2022['Evolucion_ventas_total']=df_2020_2022['Ingresos de explotación\nmil EUR\n2022']-df_2020_2022['Ingresos de explotación\nmil EUR\n2020'].astype(float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Financial Export limit reached'

# %%
df_2020_2022['ROA']=df_2020_2022['Resultado del Ejercicio\nmil EUR\n2022']/df_2020_2022['Total activo\nmil EUR\n2022']

# %%
df_2020_2022.drop(columns=['Resultado del Ejercicio\nmil EUR\n2022',
        'Ingresos de explotación\nmil EUR\n2022',
       'Activo circulante\nmil EUR\n2022', 'Pasivo líquido\nmil EUR\n2022',
       'Resultado Explotación\nmil EUR\n2022',
       'Otros activos líquidos\nmil EUR\n2022',
       'Capital suscrito\nmil EUR\n2022',
       'Otros fondos propios\nmil EUR\n2022',
       'Ingresos de explotación\nmil EUR\n2020'], inplace=True)
